# %%
import pandas as pd

# Création du DataFrame avec les colonnes latitude et longitude
data = {
    'latitude': [46.16],
    'longitude': [1.86]
}

df = pd.DataFrame(data)

# Affichage du DataFrame
print(df)
# Out:
#    latitude  longitude
# 0     46.16       1.86

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.to_csv("/content/drive/MyDrive/cinema", index=False)
